# %% [markdown]
# <a href="https://colab.research.google.com/github/MaluWhoo/imersao-dados-alura/blob/main/Todas_as_Aulas_Imers%C3%A3o_dados_com_Python_Alura_Agosto_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 1 - Análise de Dados com Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv')

# %%
df.head(10)
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
# 5     2025.0               EN              FT       Data Engineer   80000
# 6     2025.0               SE              FT      Data Scientist  185000
# 7     2025.0               SE              FT      Data Scientist  148000
# 8     2025.0               MI              FT      Data Scientist  135000
# 9     2025.0               MI              FT      Data Scientist  108000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape #Primeiro número é a quant. de linhas é o segundo de colunas
# Out:
# (133349, 11)

# %%
linhas, colunas = df.shape[0], df.shape [1]
print ('Linhas:', linhas)
print ('Colunas:', colunas )
# Out:
# Linhas: 133349
# Colunas: 11

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
# feita a partir da IA

renomear_colunas = {
    'work_year': 'ano',
    'experience_level':  'senioridade',
    'employment_type': 'contrato',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'moeda',
    'salary_in_usd': 'usd',
    'employee_residence': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'empresa',
    'company_size': 'tamanho_empresa'
}

df.rename(columns=renomear_colunas, inplace=True)
df.columns
# Out:
# Index(['ano', 'senioridade', 'contrato', 'cargo', 'salario', 'moeda', 'usd',
#        'residencia', 'remoto', 'empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
df["senioridade"].value_counts()
# Out:
# senioridade
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
df["contrato"].value_counts()
# Out:
# contrato
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
df["remoto"].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
df["tamanho_empresa"].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
# prompt: trazuda para português as categorias da coluna "senioridade" do dataframe DF

senioridade = {
    'SE': 'Senior',
    'MI': 'Pleno',
    'EN': 'Junior',
    'EX': 'Executivo'
}
df['senioridade'] = df['senioridade'].replace(senioridade)
df['senioridade'].value_counts()
# Out:
# senioridade
# Senior       77241
# Pleno        40465
# Junior       12443
# Executivo     3200
# Name: count, dtype: int64

# %%
contrato = {
    'FT': 'Tempo Integral',
    'CT': 'Contrato',
    'PT': 'Tempo Parcial',
    'FL': 'Freelancer'
}
df['contrato'] = df['contrato'].replace(contrato)
df['contrato'].value_counts()
# Out:
# contrato
# Tempo Integral    132563
# Contrato             394
# Tempo Parcial        376
# Freelancer            16
# Name: count, dtype: int64

# %%
tamanho_empresa = {
    'M': 'Médio',
    'L': 'Grande',
    'S': 'Pequeno'
}
df['tamanho_empresa'] = df['tamanho_empresa'].replace(tamanho_empresa)
df['tamanho_empresa'].value_counts()
# Out:
# tamanho_empresa
# Médio      129561
# Grande       3574
# Pequeno       214
# Name: count, dtype: int64

# %%
remoto = {
    0: 'Presencial',
    50: 'Híbrido',
    100: 'Remoto'
}
df['remoto'] = df['remoto'].replace(remoto)
df['remoto'].value_counts()
# Out:
# remoto
# Presencial    105312
# Remoto         27718
# Híbrido          319
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       ano senioridade        contrato               cargo  salario moeda  \
# 0  2025.0      Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0      Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Junior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df.describe(include='object')
# Out:
#        senioridade        contrato           cargo   moeda residencia  \
# count       133349          133349          133349  133349     133349
# unique           4               4             390      26        102
# top         Senior  Tempo Integral  Data Scientist     USD         US
# freq         77241          132563           17314  126140     119579
#
#             remoto empresa tamanho_empresa
# count       133349  133349          133349
# unique           3      95               3
# top     Presencial      US           Médio
# freq        105312  119641          129561

# %%
df.describe()
# Out:
#                  ano       salario            usd
# count  133339.000000  1.333490e+05  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098
# std         0.680627  2.173860e+05   74288.363097
# min      2020.000000  1.400000e+04   15000.000000
# 25%      2024.000000  1.060200e+05  106000.000000
# 50%      2024.000000  1.470000e+05  146206.000000
# 75%      2025.000000  1.990000e+05  198000.000000
# max      2025.000000  3.040000e+07  800000.000000

# %% [markdown]
# # Aula 2 - Preparação e Limpeza de Dados

# %%
df.isnull() #FALSE - Onde não tem dado nulo
            #TRUE - Onde tem dado nulo
# Out:
#           ano  senioridade  contrato  cargo  salario  moeda    usd  \
# 0       False        False     False  False    False  False  False
# 1       False        False     False  False    False  False  False
# 2       False        False     False  False    False  False  False
# 3       False        False     False  False    False  False  False
# 4       False        False     False  False    False  False  False
# ...       ...          ...       ...    ...      ...    ...    ...
# 133344  False        False     False  False    False  False  False
# 133345  False        False     False  False    False  False  False
# 133346  False        False     False  False    False  False  False
# 133347  False        False     False  False    False  False  False
# 133348  False        False     False  False    False  False  False
#
#         residencia  remoto  empresa  tamanho_empresa
# 0            False   False    False            False
# 1            False   False    False            False
# ...

# %%
df.head()
# Out:
#       ano senioridade        contrato               cargo  salario moeda  \
# 0  2025.0      Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0      Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Junior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df.isnull().sum()

# ANO 10 - 10 pessoas dessa base de mais de 30 mil resgistros não tem a variavel ano preenchida
# Out:
# ano                10
# senioridade         0
# contrato            0
# cargo               0
# salario             0
# moeda               0
# usd                 0
# residencia          0
# remoto              0
# empresa             0
# tamanho_empresa     0
# dtype: int64

# %%
df["ano"].unique()

# nan - valor nulo
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
df[df.isnull().any(axis=1)]

# a base e todas que na ccategoria ano é nulo
# Out:
#         ano senioridade        contrato                      cargo  salario  \
# 5588    NaN      Senior  Tempo Integral            Product Manager   184500
# 59692   NaN       Pleno  Tempo Integral                   Engineer   110000
# 59710   NaN      Junior  Tempo Integral             Data Scientist   208800
# 59759   NaN      Senior  Tempo Integral          Software Engineer   135000
# 59789   NaN      Senior  Tempo Integral                   Engineer   112000
# 131000  NaN      Senior  Tempo Integral  Machine Learning Engineer   163800
# 131006  NaN      Senior  Tempo Integral     Data Analytics Manager   204500
# 133054  NaN      Junior  Tempo Integral             Data Scientist    40000
# 133281  NaN       Pleno  Tempo Integral  Machine Learning Engineer   180000
# 133317  NaN       Pleno  Tempo Integral             Data Scientist   130000
#
#        moeda     usd residencia      remoto empresa tamanho_empresa
# ...

# %%
# Criação de um Data Frame

import numpy as np
df_salarios = pd.DataFrame({
    'nome': ['Anna', 'Miau', 'Harry', 'Rony', 'Val'],
    'salario': [4000, np.nan, 5000, np.nan, 100000] # defidindo um valor nulo
})

## Calculo da Média e substitui os nulos pela média e arredonda os valores
# df_salarios - é a nossa base
# ['salario_media'] - é a coluna nova que estamos criando

# dentro da base df_salarios, vamos preencher (fillna). Com o que será preenchido: com os salarios .mean que é a média
# .round2 - arredondar para duas casas decimais
df_salarios ['salario_media'] = df_salarios ['salario'].fillna(df_salarios ['salario'].mean().round(2))

## Calculo de Mediana e substitui os nulos pela mediana

df_salarios ['salario_mediana'] = df_salarios ['salario'].fillna(df_salarios ['salario'].median())
df_salarios
# Out:
#     nome   salario  salario_media  salario_mediana
# 0   Anna    4000.0        4000.00           4000.0
# 1   Miau       NaN       36333.33           5000.0
# 2  Harry    5000.0        5000.00           5000.0
# 3   Rony       NaN       36333.33           5000.0
# 4    Val  100000.0      100000.00         100000.0

# %%
# Outro Data Frame

df_temperaturas = pd.DataFrame({
    'Dia': ['Segunda-Feira', 'Terça-Feira', 'Quarta-Feira', 'Quinta-feira', 'Sexta-Feira'], # Criando as colunas
    'Temperatura': [30, np.nan, np.nan, 28, 27]
})

#

df_temperaturas['Preenchido_ffill'] = df_temperaturas['Temperatura'].ffill() # Criando uma nova coluna
df_temperaturas
# Out:
#              Dia  Temperatura  Preenchido_ffill
# 0  Segunda-Feira         30.0              30.0
# 1    Terça-Feira          NaN              30.0
# 2   Quarta-Feira          NaN              30.0
# 3   Quinta-feira         28.0              28.0
# 4    Sexta-Feira         27.0              27.0

# %%
df_temperaturas = pd.DataFrame({
    'Dia': ['Segunda-Feira', 'Terça-Feira', 'Quarta-Feira', 'Quinta-feira', 'Sexta-Feira'], # Criando as colunas
    'Temperatura': [30, np.nan, np.nan, 28, 27]
})

#

df_temperaturas['Preenchido_ffill'] = df_temperaturas['Temperatura'].ffill() # Criando uma nova coluna
df_temperaturas
# Out:
#              Dia  Temperatura  Preenchido_ffill
# 0  Segunda-Feira         30.0              30.0
# 1    Terça-Feira          NaN              30.0
# 2   Quarta-Feira          NaN              30.0
# 3   Quinta-feira         28.0              28.0
# 4    Sexta-Feira         27.0              27.0

# %%
df_cidades = pd.DataFrame({
    'Nome:': ['Anna', 'Miau', 'Harry', 'Rony', 'Val'],
    'Cidade:': ['São Paulo', np.nan, 'Curitiba', np.nan, 'Belém']
})

df_cidades['Cidade_Preenchida'] = df_cidades['Cidade:'].fillna('Não informado!')
display(df_cidades)
# Out:
#    Nome:    Cidade: Cidade_Preenchida
# 0   Anna  São Paulo         São Paulo
# 1   Miau        NaN    Não informado!
# 2  Harry   Curitiba          Curitiba
# 3   Rony        NaN    Não informado!
# 4    Val      Belém             Belém

# %%
# Variavel com os dados limpos
df_limpo = df.dropna()

# %%
df_limpo.isnull().sum()
# Out:
# ano                0
# senioridade        0
# contrato           0
# cargo              0
# salario            0
# moeda              0
# usd                0
# residencia         0
# remoto             0
# empresa            0
# tamanho_empresa    0
# dtype: int64

# %%
df_limpo.head()
# Out:
#       ano senioridade        contrato               cargo  salario moeda  \
# 0  2025.0      Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0      Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Junior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  float64
#  1   senioridade      133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  int64
#  5   moeda            133339 non-null  object
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  object
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.2+ MB

# %%
''' Na base de dados df_limpo, ela recebe df_limpo no qual ele vai ser reconfigurado assign,
    e nisso vamos mudar toda a coluna ano mas agora com um inteiro
'''
df_limpo = df_limpo.assign(ano = df_limpo['ano'].astype('int64'))

# %% [markdown]
# # Aula 3 - Vizualização de Dados

# %% [markdown]
# Apredendo a criar gráficos estátisticos para explorar e comuninar as informações presentes nos dados. Histogramas, boxplots, barras, etc.

# %%
df_limpo.head()
# Out:
#     ano senioridade        contrato               cargo  salario moeda  \
# 0  2025      Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025      Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025      Junior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df_limpo['senioridade'].value_counts().plot(kind='bar', title='Distribuição de Senioridade')
# Out:
# <Axes: title={'center': 'Distribuição de Senioridade'}, xlabel='senioridade'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(data=df_limpo, x='senioridade', y='usd')
# Out:
# <Axes: xlabel='senioridade', ylabel='usd'>

# %%
plt.figure(figsize=(8, 5)) # Definimmos o tamanho
sns.barplot(data=df_limpo, x='senioridade', y='usd')
plt.title(' Salários Médio por Senioridade')
plt.xlabel('Senioridade') # label = rótulo
plt.ylabel('Salário Médio Anual (USD)')
plt.show()

# %%
df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=False)
# Out:
# senioridade
# Executivo    202027.667813
# Senior       172850.838301
# Pleno        143044.845979
# Junior        99034.963267
# Name: usd, dtype: float64

# %%
ordem = df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=False).index
ordem
# Out:
# Index(['Executivo', 'Senior', 'Pleno', 'Junior'], dtype='object', name='senioridade')

# %%
plt.figure(figsize=(8, 5)) # Definimmos o tamanho
sns.barplot(data=df_limpo, x='senioridade', y='usd', order=ordem)
plt.title(' Salários Médio por Senioridade')
plt.xlabel('Senioridade') # label = rótulo
plt.ylabel('Salário Médio Anual (USD)')
plt.show()

# %%
## histogram

plt.figure(figsize=(10, 5)) # tamanho
sns.histplot(df_limpo['usd'], bins=50, kde=True) # bins - largura das barras
plt.title('Distribuição de Salários Anuais')
plt.xlabel('Salário (USD)')
plt.ylabel('Frequência')
plt.show()

# %%
plt.figure(figsize=(8, 5)) # tamanho
sns.boxplot(x=df_limpo['usd'])
plt.title('Boxplot Salário')
plt.xlabel('Salário (USD)')
plt.show()

# A linha no meio da caixa é a mediana
# Outliers - Dados discrepantes que estão fora do intervalo (os pontos fora do azul)

# %%
order_senioridade = ['Junior', 'Pleno', 'Senior', 'Executivo']

plt.figure(figsize=(8, 5)) # tamanho
sns.boxplot(x='senioridade', y='usd', data=df_limpo, order=order_senioridade)
plt.title('Distruibuição Salarial por Senioridade')
plt.xlabel('Salário (USD)')
plt.show()

# %%
order_senioridade = ['Junior', 'Pleno', 'Senior', 'Executivo']

plt.figure(figsize=(8, 5)) # tamanho
sns.boxplot(x='senioridade', y='usd', data=df_limpo, order=order_senioridade, palette='Set2', hue='senioridade')
plt.title('Distruibuição Salarial por Senioridade')
plt.xlabel('Salário (USD)')
plt.show()

# %% [markdown]
# **Gráficos Interativos**

# %%
import plotly.express as px

# %%
# Criando um gráfico de barras interativo com Plotly - USANDO IA
fig = px.bar(
    df_limpo.groupby('senioridade')['usd'].mean().reset_index(), # Agrupando por senioridade e calculando a média
    x='senioridade',
    y='usd',
    title='Salários Médio por Senioridade (Plotly)',
    labels={'senioridade': 'Senioridade', 'usd': 'Salário Médio Anual (USD)'}, # Rótulos
    color='senioridade' # Colorindo as barras por senioridade
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem =  df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['Tipo Trabalho', 'Quantidade']

# Grafico de Pizza
fig = px.pie(
    remoto_contagem,
    names='Tipo Trabalho',
    values='Quantidade',
    title='Proporção dos Tipos de Trabalho'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem =  df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['Tipo Trabalho', 'Quantidade']

# Grafico de Rosquinha
fig = px.pie(
    remoto_contagem,
    names='Tipo Trabalho',
    values='Quantidade',
    title='Proporção dos Tipos de Trabalho',
    hole=0.5 # Tamanho do circulo
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem =  df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['Tipo Trabalho', 'Quantidade']

# Grafico de Rosquinha
fig = px.pie(
    remoto_contagem,
    names='Tipo Trabalho',
    values='Quantidade',
    title='Proporção dos Tipos de Trabalho',
    hole=0.5 # Tamanho do circulo
)

fig.update_traces(textinfo='percent+label') # Adicionando texto
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Desafio da Aula 3:

# %% [markdown]
# Cargo - Data Science - Gerar uma visualização de salario médio por país usando o gráfico interativo.

# %%
# Filtrar o DataFrame para cargos de 'Data Scientist'
df_data_scientist = df_limpo[df_limpo['cargo'] == 'Data Scientist'].copy()

# Calcular o salário médio por país
salario_por_pais = df_data_scientist.groupby('empresa')['usd'].mean().reset_index()

# Criar o gráfico de barras interativo
fig = px.bar(
    salario_por_pais,
    x='empresa',
    y='usd',
    title='Salário Médio de Data Scientists por País',
    labels={'empresa': 'País', 'usd': 'Salário Médio Anual (USD)'},
    color='empresa'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Aula 4 - Construindo um Dashboard com Streamlit

# %% [markdown]
# Aprendendo a usar a biblioteca Streamlit para a criação de um
# dashboard interativo simples, que permite visualizar dados filtrados e gerar gráficos de forma prática.

# %% [markdown]
# Fazendo o 4° gráfico que será apresentado no dashboard, gráfico de mapa. Correção também do desafio

# %%
df.head()
# Out:
#       ano senioridade        contrato               cargo  salario moeda  \
# 0  2025.0      Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0      Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Junior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
pip install pycountry

# %%
import pycountry

# Função converter ISO-2 para ISO-3 = Converte sigla de países com 2 letras para 3.
def iso_to_iso3(code):
  try:
    return pycountry.countries.get(alpha_2=code).alpha_3
  except:
    return None

# Nova coluna com a sigla ISO 3
df_limpo ['residencia_iso3'] = df_limpo['residencia'].apply(iso_to_iso3)

# Calcular Média Salarial por país (ISO-3)
df_ds = df_limpo[df_limpo['cargo'] == 'Data Scientist']
media_por_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()

# Gerar o mapa
fig = px.choropleth(
    media_por_pais,
    locations='residencia_iso3',
    color='usd',
    color_continuous_scale='rdylgn',
    title='Salário Médio por País (Data Scientist)',
    labels={'usd': 'Salário Médio (USD)', 'residencia_iso3': 'País'}
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_limpo.head()
# Out:
#     ano senioridade        contrato               cargo  salario moeda  \
# 0  2025      Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025      Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025      Junior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa residencia_iso3
# 0  214000         US      Remoto      US           Médio             USA
# 1  136000         US      Remoto      US           Médio             USA
# 2  158800         AU  Presencial      AU           Médio             AUS
# 3  139200         AU  Presencial      AU           Médio             AUS
# 4   90000         US  Presencial      US           Médio             USA

# %%
df_limpo.to_csv('dados-imersao-final', index=False)
